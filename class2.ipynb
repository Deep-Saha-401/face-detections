# %%
import cv2

# %%
from deepface import DeepFace
# Out:
# Directory  C:\Users\Deep Saha /.deepface created
# Directory  C:\Users\Deep Saha /.deepface/weights created

# %%
import matplotlib.pyplot as plt

# %%
img = cv2.imread('happy boy.jpg')

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
prediction = DeepFace.analyze(img)
# Out:
# facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: C:\Users\Deep Saha\.deepface\weights\facial_expression_model_weights.h5
# 100%|█████████████████████████████████████████████████████████████████████████████| 5.98M/5.98M [00:02<00:00, 2.45MB/s]
# age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: C:\Users\Deep Saha\.deepface\weights\age_model_weights.h5
# 100%|███████████████████████████████████████████████████████████████████████████████| 539M/539M [02:38<00:00, 3.40MB/s]
# gender_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/gender_model_weights.h5
# To: C:\Users\Deep Saha\.deepface\weights\gender_model_weights.h5
# ...

# %%
predictions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 predictions
#
# NameError: name 'predictions' is not defined

# %%
prediction
# Out:
# {'emotion': {'angry': 1.3240205728546487e-09,
#   'disgust': 4.945073508510048e-12,
#   'fear': 1.3860097230043227e-08,
#   'happy': 99.99874234192028,
#   'sad': 4.366046451487564e-07,
#   'surprise': 8.796139688559583e-10,
#   'neutral': 0.0012581423856805663},
#  'dominant_emotion': 'happy',
#  'region': {'x': 356, 'y': 206, 'w': 497, 'h': 497},
#  'age': 27,
#  'gender': 'Woman',
#  'race': {'asian': 1.261849794536829,
#   'indian': 1.9828269258141518,
#   'black': 0.1971276942640543,
#   'white': 54.024481773376465,
#   'middle eastern': 24.131634831428528,
#   'latino hispanic': 18.40207427740097},
#  'dominant_race': 'white'}

# %%
type(prediction)
# Out:
# dict

# %%
prediction['dominant_emotion']
# Out:
# 'happy'

# %%
prediction['dominant_race']
# Out:
# 'white'

# %%
prediction['gender']
# Out:
# 'Woman'

# %% [markdown]
# # We are trying to Draw a rectangle accross the face

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray =cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
face = faceCascade.detectMultiScale(gray,1.1,4)

# %%
for(x,y,w,h) in face:
    cv2.rectangle(img,(x,y),(x+w, y+h),(0,255,0),2)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
# using putText() method for instrting text on vedio

cv2.putText(img, prediction['dominant_emotion'],(225,250),font,7,(0,5,255),2,cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
# using putText() method for instrting text on vedio

cv2.putText(img, prediction['dominant_emotion'],(225,250),font,7,(0,5,255),2,cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread('fear.webp')

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
prediction = DeepFace.analyze(img)
# Out:
# ...
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00,  4.28it/s]

# %%
prediction
# Out:
# {'emotion': {'angry': 0.04513005595500845,
#   'disgust': 4.0341832700328756e-09,
#   'fear': 65.7543044383163,
#   'happy': 0.254228820520184,
#   'sad': 13.89029307481133,
#   'surprise': 19.70892611635612,
#   'neutral': 0.34711764247058124},
#  'dominant_emotion': 'fear',
#  'region': {'x': 52, 'y': 60, 'w': 106, 'h': 106},
#  'age': 29,
#  'gender': 'Man',
#  'race': {'asian': 10.313476622104645,
#   'indian': 12.285180389881134,
#   'black': 12.178308516740799,
#   'white': 16.946713626384735,
#   'middle eastern': 11.899124830961227,
#   'latino hispanic': 36.37720048427582},
#  'dominant_race': 'latino hispanic'}

# %%
prediction['dominant_emotion']
# Out:
# 'fear'

# %%
prediction['dominant_race']
# Out:
# 'latino hispanic'

# %%
prediction['gender']
# Out:
# 'Man'

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
# using putText() method for instrting text on vedio

cv2.putText(img, prediction['dominant_emotion'],(25,25),font,1,(0,5,255),2,cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
